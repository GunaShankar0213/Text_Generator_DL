# %%
# !pip install tensorflow
# !pip install transformers

# %%
import numpy as np

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.utils import to_categorical

# Example text
text = "Hello, how are you? I am doing great. What about you?"

# Tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

# Create input sequences using sliding window approach
sequences = tokenizer.texts_to_sequences([text])[0]
input_sequences = []
for i in range(1, len(sequences)):
    n_gram_sequence = sequences[:i+1]
    input_sequences.append(n_gram_sequence)

# Pad sequences
max_sequence_length = max([len(sequence) for sequence in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre'))

# Split input sequences into input and target
xs = input_sequences[:, :-1]
labels = input_sequences[:, -1]
ys = to_categorical(labels, num_classes=total_words)

# Define the model
model = Sequential()
model.add(Embedding(total_words, 10, input_length=max_sequence_length-1))
model.add(LSTM(100))
model.add(Dense(total_words, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(xs, ys, epochs=100, verbose=1)

# Generate text
seed_text = "Hello,"
next_words = 5

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_length-1, padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word

print("Generated Text:", seed_text)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3974 - accuracy: 0.2000
# Epoch 2/100
# 1/1 [==============================] - 0s 15ms/step - loss: 2.3941 - accuracy: 0.3000
# Epoch 3/100
# 1/1 [==============================] - 0s 20ms/step - loss: 2.3907 - accuracy: 0.3000
# Epoch 4/100
# 1/1 [==============================] - 0s 21ms/step - loss: 2.3872 - accuracy: 0.3000
# Epoch 5/100
# 1/1 [==============================] - 0s 17ms/step - loss: 2.3834 - accuracy: 0.3000
# Epoch 6/100
# 1/1 [==============================] - 0s 18ms/step - loss: 2.3793 - accuracy: 0.2000
# Epoch 7/100
# 1/1 [==============================] - 0s 22ms/step - loss: 2.3748 - accuracy: 0.2000
# Epoch 8/100
# 1/1 [==============================] - 0s 18ms/step - loss: 2.3699 - accuracy: 0.2000
# Epoch 9/100
# 1/1 [==============================] - 0s 17ms/step - loss: 2.3644 - accuracy: 0.2000
# Epoch 10/100
# 1/1 [==============================] - 0s 18ms/step - loss: 2.3582 - accuracy: 0.2000
# Epoch 11/100
# 1/1 [==============================] - 0s 19ms/step - loss: 2.3512 - accuracy: 0.2000
# Epoch 12/100
# 1/1 [==============================] - 0s 18ms/step - loss: 2.3432 - accuracy: 0.2000
# Epoch 13/100
# 1/1 [==============================] - 0s 17ms/step - loss: 2.3341 - accuracy: 0.2000
# Epoch 14/100
# 1/1 [==============================] - 0s 16ms/step - loss: 2.3236 - accuracy: 0.2000
# Epoch 15/100
# 1/1 [==============================] - 0s 16ms/step - loss: 2.3116 - accuracy: 0.2000
# Epoch 16/100
# 1/1 [==============================] - 0s 15ms/step - loss: 2.2978 - accuracy: 0.2000
# Epoch 17/100
# 1/1 [==============================] - 0s 17ms/step - loss: 2.2820 - accuracy: 0.2000
# Epoch 18/100
# 1/1 [==============================] - 0s 17ms/step - loss: 2.2641 - accuracy: 0.2000
# Epoch 19/100
# 1/1 [==============================] - 0s 17ms/step - loss: 2.2442 - accuracy: 0.2000
# Epoch 20/100
# 1/1 [==============================] - 0s 19ms/step - loss: 2.2229 - accuracy: 0.2000
# Epoch 21/100
# 1/1 [==============================] - 0s 22ms/step - loss: 2.2017 - accuracy: 0.2000
# Epoch 22/100
# 1/1 [==============================] - 0s 17ms/step - loss: 2.1834 - accuracy: 0.2000
# Epoch 23/100
# 1/1 [==============================] - 0s 19ms/step - loss: 2.1722 - accuracy: 0.2000
# Epoch 24/100
# 1/1 [==============================] - 0s 18ms/step - loss: 2.1684 - accuracy: 0.2000
# Epoch 25/100
# 1/1 [==============================] - 0s 19ms/step - loss: 2.1635 - accuracy: 0.2000
# Epoch 26/100
# 1/1 [==============================] - 0s 17ms/step - loss: 2.1510 - accuracy: 0.2000
# Epoch 27/100
# 1/1 [==============================] - 0s 22ms/step - loss: 2.1336 - accuracy: 0.2000
# Epoch 28/100
# 1/1 [==============================] - 0s 19ms/step - loss: 2.1165 - accuracy: 0.2000
# Epoch 29/100
# 1/1 [==============================] - 0s 22ms/step - loss: 2.1030 - accuracy: 0.2000
# Epoch 30/100
# 1/1 [==============================] - 0s 23ms/step - loss: 2.0928 - accuracy: 0.2000
# Epoch 31/100
# 1/1 [==============================] - 0s 18ms/step - loss: 2.0840 - accuracy: 0.2000
# Epoch 32/100
# 1/1 [==============================] - 0s 19ms/step - loss: 2.0743 - accuracy: 0.2000
# Epoch 33/100
# 1/1 [==============================] - 0s 18ms/step - loss: 2.0620 - accuracy: 0.2000
# Epoch 34/100
# 1/1 [==============================] - 0s 19ms/step - loss: 2.0463 - accuracy: 0.3000
# Epoch 35/100
# 1/1 [==============================] - 0s 19ms/step - loss: 2.0268 - accuracy: 0.3000
# Epoch 36/100
# 1/1 [==============================] - 0s 20ms/step - loss: 2.0037 - accuracy: 0.3000
# Epoch 37/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.9773 - accuracy: 0.2000
# Epoch 38/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.9475 - accuracy: 0.2000
# Epoch 39/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.9138 - accuracy: 0.2000
# Epoch 40/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1.8761 - accuracy: 0.3000
# Epoch 41/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1.8363 - accuracy: 0.3000
# Epoch 42/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.7982 - accuracy: 0.2000
# Epoch 43/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1.7622 - accuracy: 0.2000
# Epoch 44/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.7240 - accuracy: 0.2000
# Epoch 45/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.6849 - accuracy: 0.2000
# Epoch 46/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.6510 - accuracy: 0.2000
# Epoch 47/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.6192 - accuracy: 0.3000
# Epoch 48/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1.5883 - accuracy: 0.3000
# Epoch 49/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1.5610 - accuracy: 0.3000
# Epoch 50/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.5304 - accuracy: 0.4000
# Epoch 51/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1.5021 - accuracy: 0.5000
# Epoch 52/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1.4711 - accuracy: 0.8000
# Epoch 53/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1.4415 - accuracy: 0.7000
# Epoch 54/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.4086 - accuracy: 0.7000
# Epoch 55/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1.3777 - accuracy: 0.8000
# Epoch 56/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3442 - accuracy: 0.8000
# Epoch 57/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3126 - accuracy: 0.8000
# Epoch 58/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1.2835 - accuracy: 0.7000
# Epoch 59/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1.2535 - accuracy: 0.7000
# Epoch 60/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.2216 - accuracy: 0.7000
# Epoch 61/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1.1892 - accuracy: 0.6000
# Epoch 62/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1.1565 - accuracy: 0.6000
# Epoch 63/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.1283 - accuracy: 0.7000
# Epoch 64/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.1195 - accuracy: 0.7000
# Epoch 65/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.0688 - accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.0299 - accuracy: 0.8000
# Epoch 67/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.0195 - accuracy: 0.8000
# Epoch 68/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.9814 - accuracy: 0.8000
# Epoch 69/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.9454 - accuracy: 0.8000
# Epoch 70/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.9246 - accuracy: 0.8000
# Epoch 71/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.9046 - accuracy: 0.9000
# Epoch 72/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.8869 - accuracy: 0.8000
# Epoch 73/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.8360 - accuracy: 0.9000
# Epoch 74/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.8074 - accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.8036 - accuracy: 0.8000
# Epoch 76/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.7886 - accuracy: 0.9000
# Epoch 77/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7762 - accuracy: 0.8000
# Epoch 78/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.7102 - accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7255 - accuracy: 0.9000
# Epoch 80/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7645 - accuracy: 0.7000
# Epoch 81/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6520 - accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.7814 - accuracy: 0.7000
# Epoch 83/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7283 - accuracy: 0.7000
# Epoch 84/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7415 - accuracy: 0.7000
# Epoch 85/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6021 - accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.7395 - accuracy: 0.7000
# Epoch 87/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5916 - accuracy: 0.8000
# Epoch 88/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6982 - accuracy: 0.7000
# Epoch 89/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5869 - accuracy: 0.8000
# Epoch 90/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5842 - accuracy: 0.8000
# Epoch 91/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6093 - accuracy: 0.7000
# Epoch 92/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5261 - accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5830 - accuracy: 0.8000
# Epoch 94/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5449 - accuracy: 0.8000
# Epoch 95/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4985 - accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5467 - accuracy: 0.7000
# Epoch 97/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.4877 - accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.4875 - accuracy: 0.9000
# Epoch 99/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5026 - accuracy: 0.8000
# Epoch 100/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4615 - accuracy: 0.9000
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Generated Text: Hello, how are you i am

# %%
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# Generated Text: Hello, how how you i am doing great what about you
